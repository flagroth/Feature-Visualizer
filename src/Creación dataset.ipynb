# %%
import pandas as pd

# %%
attributes = pd.read_csv("../data/PlayerAttributeData.csv")
personal = pd.read_csv("../data/PlayerPersonalData.csv")
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (11,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dataset = pd.concat([personal, attributes], axis=1)
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'ID', 'Name', 'Age', 'Photo',
#        'Nationality', 'Flag', 'Overall', 'Potential', 'Club', 'Club Logo',
#        'Value', 'Wage', 'Special', 'Unnamed: 0', 'Acceleration', 'Aggression',
#        'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve',
#        'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving',
#        'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
#        'Heading accuracy', 'ID', 'Interceptions', 'Jumping', 'Long passing',
#        'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions',
#        'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed',
#        'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys'],
#       dtype='object')

# %%
dataset = dataset.drop(['Unnamed: 0','Unnamed: 0.1','Photo','Flag', 
                        'Nationality','Club Logo','Value','Wage',
                        'Club','Special'], axis = 1)
dataset.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Overall', 'Potential', 'Acceleration',
#        'Aggression', 'Agility', 'Balance', 'Ball control', 'Composure',
#        'Crossing', 'Curve', 'Dribbling', 'Finishing', 'Free kick accuracy',
#        'GK diving', 'GK handling', 'GK kicking', 'GK positioning',
#        'GK reflexes', 'Heading accuracy', 'ID', 'Interceptions', 'Jumping',
#        'Long passing', 'Long shots', 'Marking', 'Penalties', 'Positioning',
#        'Reactions', 'Short passing', 'Shot power', 'Sliding tackle',
#        'Sprint speed', 'Stamina', 'Standing tackle', 'Strength', 'Vision',
#        'Volleys'],
#       dtype='object')

# %%
dataset.to_csv("../data/dataset_attributes.csv", index = False)

# %%
dataset
# Out:
#            ID               Name  Age  Overall  Potential Acceleration  \
# 0       20801  Cristiano Ronaldo   32       94         94           89
# 1      158023           L. Messi   30       93         93           92
# 2      190871             Neymar   25       92         94           94
# 3      176580          L. Suárez   30       92         92           88
# 4      167495           M. Neuer   31       92         92           58
# 5      188545     R. Lewandowski   28       91         91           79
# 6      193080             De Gea   26       90         92           57
# 7      183277          E. Hazard   26       90         91           93
# 8      182521           T. Kroos   27       90         90           60
# 9      167664         G. Higuaín   29       90         90           78
# 10     155862       Sergio Ramos   31       90         90           75
# 11     192985       K. De Bruyne   26       89         92           76
# ...
